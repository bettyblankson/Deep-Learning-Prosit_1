# %% [markdown]
# <a href="https://colab.research.google.com/github/bettyblankson/Deep-Learning-Prosit_1/blob/main/DL_feedforward.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F
import seaborn as sns
import zipfile
import os

# %%
# !rm -rf /content/CINIC-10   # remove if it already exists
# !mkdir /content/CINIC-10
# !unzip -q "/content/drive/MyDrive/CINIC-10.zip" -d /content/CINIC-10
# !ls /content/CINIC-10
# Out:
# imagenet-contributors.csv  synsets-to-cifar-10-classes.txt  train
# README.md		   test				    valid

# %%
data_dir = '/content/CINIC-10'

# %%
class SimpleDNN(nn.Module):
    def __init__(self, input_dim=32*32*3, hidden_sizes=[512,256,128,64], n_classes=10, dropout=0.5):
        super().__init__()
        layers = []
        in_dim = input_dim

        #Track which indices are the last two hidden layers
        last_two = {len(hidden_sizes)-2, len(hidden_sizes)-1}

        for i, h in enumerate(hidden_sizes):
            layers.append(nn.Linear(in_dim, h))
            layers.append(nn.BatchNorm1d(h))
            layers.append(nn.ReLU(inplace=True))


            if i in last_two:
                layers.append(nn.Dropout(dropout))

            in_dim = h

        layers.append(nn.Linear(in_dim, n_classes))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        return self.net(x)

# %%
def get_loaders(data_dir, batch_size=256):

    # CINIC-10 mean & std
    cinic_mean = [0.47889522, 0.47227842, 0.43047404]
    cinic_std  = [0.24205776, 0.23828046, 0.25874835]

    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(cinic_mean, cinic_std)  ##Normalizing the input
    ])

    train_ds = datasets.ImageFolder(os.path.join(data_dir,'train'), transform=transform)
    val_ds   = datasets.ImageFolder(os.path.join(data_dir,'valid'), transform=transform)
    test_ds  = datasets.ImageFolder(os.path.join(data_dir,'test'), transform=transform)

    return (DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=2),
            DataLoader(val_ds,   batch_size=batch_size, shuffle=False, num_workers=2),
            DataLoader(test_ds,  batch_size=batch_size, shuffle=False, num_workers=2))

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()*imgs.size(0)
        _, preds = outputs.max(1)
        correct += (preds==labels).sum().item()
        total += imgs.size(0)
    return running_loss/total, correct/total

# %%
def validate(model, loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()*imgs.size(0)
            _, preds = outputs.max(1)
            correct += (preds==labels).sum().item()
            total += imgs.size(0)
    return running_loss/total, correct/total

# %%
def test_and_report(model, test_loader, device, class_names):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Accuracy
    acc = accuracy_score(all_labels, all_preds)
    print(f"Test Accuracy: {acc * 100:.2f}%")

    # Confusion matrix
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    import matplotlib.pyplot as plt
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(10,8))
    sns.heatmap(cm, annot=False, fmt="d", xticklabels=class_names, yticklabels=class_names, cmap="Blues")
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.show()

# %%
# !ls /content/CINIC-10
# Out:
# ls: cannot access '/content/CINIC-10': No such file or directory

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
#device = 'cuda' if torch.cuda.is_available() else 'cpu'
train_loader, val_loader, test_loader = get_loaders(data_dir, batch_size=256)
class_names = train_loader.dataset.classes

model = SimpleDNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
best_val_acc = 0.0
epochs = 15

# Lists to store metrics
train_losses, val_losses = [], []
train_accs, val_accs = [], []



for epoch in range(epochs):
    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, device)
    val_loss, val_acc = validate(model, val_loader, criterion, device)
    print(f'Epoch {epoch+1}: train_loss={train_loss:.4f} train_acc={train_acc:.4f} val_loss={val_loss:.4f} val_acc={val_acc:.4f}')
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), 'best_dnn_cinic.pth')
model.load_state_dict(torch.load('best_dnn_cinic.pth', map_location=device))
test_and_report(model, test_loader, device, class_names)
# Out:
# Epoch 1: train_loss=1.9269 train_acc=0.2942 val_loss=1.7266 val_acc=0.3696
# Epoch 2: train_loss=1.7467 train_acc=0.3677 val_loss=1.6559 val_acc=0.3941
# Epoch 3: train_loss=1.6794 train_acc=0.3944 val_loss=1.6144 val_acc=0.4102
# Epoch 4: train_loss=1.6279 train_acc=0.4141 val_loss=1.5921 val_acc=0.4197
# Epoch 5: train_loss=1.5839 train_acc=0.4333 val_loss=1.5874 val_acc=0.4235
# Epoch 6: train_loss=1.5544 train_acc=0.4458 val_loss=1.5691 val_acc=0.4346
# Epoch 7: train_loss=1.5259 train_acc=0.4579 val_loss=1.5422 val_acc=0.4411
# Epoch 8: train_loss=1.4927 train_acc=0.4715 val_loss=1.5480 val_acc=0.4429
# Epoch 9: train_loss=1.4725 train_acc=0.4777 val_loss=1.5331 val_acc=0.4488
# Epoch 10: train_loss=1.4452 train_acc=0.4891 val_loss=1.5525 val_acc=0.4412
# Epoch 11: train_loss=1.4217 train_acc=0.4983 val_loss=1.5347 val_acc=0.4530
# Epoch 12: train_loss=1.3948 train_acc=0.5085 val_loss=1.5427 val_acc=0.4497
# Epoch 13: train_loss=1.3687 train_acc=0.5174 val_loss=1.5492 val_acc=0.4488
# Epoch 14: train_loss=1.3495 train_acc=0.5256 val_loss=1.5365 val_acc=0.4591
# Epoch 15: train_loss=1.3244 train_acc=0.5339 val_loss=1.5558 val_acc=0.4526
# Test Accuracy: 45.79%

# %%
# Plot Loss
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(range(1, epochs+1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, epochs+1), val_losses, label='Validation Loss',marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

# Plot Accuracy
plt.subplot(1,2,2)
plt.plot(range(1, epochs+1), train_accs, label='Train Accuracy', marker='o')
plt.plot(range(1, epochs+1), val_accs, label='Validation Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
